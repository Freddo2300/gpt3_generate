# %%
import openai
import os
import constants

# %%
openai.api_key = constants.OPENAI_API_KEY

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('articles1.csv', sep=',', nrows=100)

df=df.drop(columns=['Unnamed: 0','publication','author','date','year','month','url'])

df['content'][0]

df['review']=df.content.str[:500]

df.drop(columns='content')
# Out:
#        id                                              title  \
# 0   17283  House Republicans Fret About Winning Their Hea...
# 1   17284  Rift Between Officers and Residents as Killing...
# 2   17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3   17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4   17287  Kim Jong-un Says North Korea Is Preparing to T...
# ..    ...                                                ...
# 95  17394  Corzine Reaches $5 Million Settlement With Reg...
# 96  17395  Sears Agrees to Sell Craftsman to Stanley Blac...
# 97  17396  L.I.R.R. Train That Crashed Was Going Over Twi...
# 98  17397  Record 2016 for U.S. Auto Industry Long Road B...
# 99  17398  Macy’s Will Cut 10,000 Jobs After Poor Holiday...
#
#                                                review
# 0   WASHINGTON  —   Congressional Republicans have...
# 1   After the bullet shells get counted, the blood...
# 2   When Walt Disney’s “Bambi” opened in 1942, cri...
# 3   Death may be the great equalizer, but it isn’t...
# 4   SEOUL, South Korea  —   North Korea’s leader, ...
# ..                                                ...
# 95  After more than five years of investigations a...
# 96  The question from the analyst on Thursday was ...
# 97  A Long Island Rail Road train that crashed in ...
# 98  DETROIT  —   Unexpectedly strong sales of new ...
# 99  Struggling with sagging sales over another cru...
#
# [100 rows x 3 columns]
